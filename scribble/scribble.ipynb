# %%
import re

# %%
result = {'backend': {'name': 'simulator'},
 'calibration': {},
 'creationDate': '2017-11-04T21:51:16.880Z',
 'deleted': False,
 'id': 'c2c7c6e0341b389234b4004a44ec7921',
 'maxCredits': 3,
 'qasms': [{'data': {'additionalData': {'seed': 3726169778},
    'counts': {'00100': 1000},
    'creg_labels': 'ans[5]',
    'date': '2017-11-04T21:51:17.564Z',
    'time': 0.278681},
   'executionId': '8730a4967efc254e25e5f62cf83bb483',
   'qasm': '// draper(0b10,0b00)->00100\n\ninclude "qelib1.inc";\nqreg q[5];\ncreg ans[5];\nu2(0.0,3.141592653589793) q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu2(0.0,3.141592653589793) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.0) q[2];\nu2(0.0,3.141592653589793) q[2];\ncx q[2],q[4];\nu2(0.0,3.141592653589793) q[4];\nu2(0.0,3.141592653589793) q[4];\nu2(0.0,3.141592653589793) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.392699081698724) q[2];\nu3(-0.392699081698724,0.0,0.0) q[2];\nu2(0.0,3.141592653589793) q[2];\ncx q[2],q[4];\nu2(0.0,3.141592653589793) q[4];\nu1(0.785398163397448) q[4];\nu2(0.0,3.141592653589793) q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[4];\nu1(-0.0) q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[4];\nu1(0.0) q[4];\ncx q[3],q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[4];\nu1(0.785398163397448) q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[4];\nu1(-0.785398163397448) q[4];\nu3(-0.785398163397448,0.0,0.0) q[4];\ncx q[3],q[4];\nu3(0.785398163397448,0.0,0.0) q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[4];\nu1(-0.785398163397448) q[4];\nu3(3.141592653589793,0.0,3.141592653589793) q[4];\nu1(0.785398163397448) q[4];\nu2(0.0,3.141592653589793) q[4];\nu2(0.0,3.141592653589793) q[4];\nu1(1.570796326794897) q[3];\nu2(0.0,3.141592653589793) q[2];\nu3(0.392699081698724,0.0,0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.0) q[2];\ncx q[3],q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.392699081698724) q[2];\nu3(-0.392699081698724,0.0,0.0) q[2];\ncx q[3],q[2];\nu3(0.392699081698724,0.0,0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.0) q[2];\nu2(0.0,3.141592653589793) q[2];\nu1(0.785398163397448) q[3];\nu2(0.0,3.141592653589793) q[0];\ncx q[2],q[0];\nu2(0.0,3.141592653589793) q[0];\nu2(0.0,3.141592653589793) q[0];\nu2(0.0,3.141592653589793) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.785398163397448) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.785398163397448) q[2];\nu3(-0.785398163397448,0.0,0.0) q[2];\nu2(0.0,3.141592653589793) q[2];\ncx q[2],q[0];\nu2(0.0,3.141592653589793) q[0];\nu1(1.570796326794897) q[0];\nu2(0.0,3.141592653589793) q[2];\nu3(0.785398163397448,0.0,0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.785398163397448) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.785398163397448) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.0) q[2];\nu2(0.0,3.141592653589793) q[2];\ncx q[2],q[4];\nu2(0.0,3.141592653589793) q[4];\nu2(0.0,3.141592653589793) q[4];\nu2(0.0,3.141592653589793) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.392699081698724) q[2];\nu3(0.392699081698724,0.0,0.0) q[2];\nu2(0.0,3.141592653589793) q[2];\ncx q[2],q[4];\nu2(0.0,3.141592653589793) q[4];\nu1(-0.785398163397448) q[4];\nu2(0.0,3.141592653589793) q[2];\nu3(-0.392699081698724,0.0,0.0) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(0.392699081698724) q[2];\nu3(3.141592653589793,0.0,3.141592653589793) q[2];\nu1(-0.392699081698724) q[2];\nu2(0.0,3.141592653589793) q[2];\n\nmeasure q[3] -> ans[3];\nmeasure q[1] -> ans[1];\nmeasure q[0] -> ans[0];\nmeasure q[4] -> ans[4];\nmeasure q[2] -> ans[2];',
   'status': 'DONE'}],
 'shots': 1000,
 'status': 'COMPLETED',
 'usedCredits': 0,
 'userId': '3420e4521ca5c81ba1ecf94166d88487'}

# %%
qasm = result["qasms"][0]["qasm"].split("\n")

# %%
len(qasm)
# Out:
# 125

# %%
bla = list(filter(lambda x: re.sub(r"u1\(-?0.0\).*;", "", x), qasm))
print(len(bla))
bla
# Out:
# 113
# ['// draper(0b10,0b00)->00100',
#  'include "qelib1.inc";',
#  'qreg q[5];',
#  'creg ans[5];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'cx q[2],q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.392699081698724) q[2];',
#  'u3(-0.392699081698724,0.0,0.0) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'cx q[2],q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u1(0.785398163397448) q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[4];',
#  'cx q[3],q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[4];',
#  'u1(0.785398163397448) q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[4];',
#  'u1(-0.785398163397448) q[4];',
#  'u3(-0.785398163397448,0.0,0.0) q[4];',
#  'cx q[3],q[4];',
#  'u3(0.785398163397448,0.0,0.0) q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[4];',
#  'u1(-0.785398163397448) q[4];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[4];',
#  'u1(0.785398163397448) q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u1(1.570796326794897) q[3];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(0.392699081698724,0.0,0.0) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'cx q[3],q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.392699081698724) q[2];',
#  'u3(-0.392699081698724,0.0,0.0) q[2];',
#  'cx q[3],q[2];',
#  'u3(0.392699081698724,0.0,0.0) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u1(0.785398163397448) q[3];',
#  'u2(0.0,3.141592653589793) q[0];',
#  'cx q[2],q[0];',
#  'u2(0.0,3.141592653589793) q[0];',
#  'u2(0.0,3.141592653589793) q[0];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.785398163397448) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.785398163397448) q[2];',
#  'u3(-0.785398163397448,0.0,0.0) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'cx q[2],q[0];',
#  'u2(0.0,3.141592653589793) q[0];',
#  'u1(1.570796326794897) q[0];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(0.785398163397448,0.0,0.0) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.785398163397448) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.785398163397448) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'cx q[2],q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.392699081698724) q[2];',
#  'u3(0.392699081698724,0.0,0.0) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'cx q[2],q[4];',
#  'u2(0.0,3.141592653589793) q[4];',
#  'u1(-0.785398163397448) q[4];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'u3(-0.392699081698724,0.0,0.0) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(0.392699081698724) q[2];',
#  'u3(3.141592653589793,0.0,3.141592653589793) q[2];',
#  'u1(-0.392699081698724) q[2];',
#  'u2(0.0,3.141592653589793) q[2];',
#  'measure q[3] -> ans[3];',
#  'measure q[1] -> ans[1];',
#  'measure q[0] -> ans[0];',
#  'measure q[4] -> ans[4];',
#  'measure q[2] -> ans[2];']

# %%
from algorithms import draper
from matplotlib import pyplot
import numpy as np
from qiskit import QuantumProgram, QuantumRegister, QuantumCircuit, Result

# %%
from interfaces import ApiCredentials
import credentials

creds = ApiCredentials()

Q_program: QuantumProgram = QuantumProgram()
Q_program.set_api(creds.GetToken(), creds.GetApiUri())

# %%
jobs = Q_program.get_api().get_jobs(limit=100000)

# %%
import re

data = filter(lambda x: x["status"] == "COMPLETED",jobs)
data = map(FlattenData, data)
data = filter(lambda x: len(x["target"]) > 0, data)
data = map(MapToMeaning, data)

list(data)
# Out:
# ["['2017-11-04T21:29:14.819Z', False, 'ibmqx4', '0b00', '0b00', '00000', 0.125, '10000', 0.32, '2_1__']",
#  "['2017-11-04T21:22:34.948Z', True, 'ibmqx4', '0b00', '0b11', '11101', 0.18, '11101', 0.18, '2_1__']",
#  "['2017-11-04T21:15:00.305Z', False, 'ibmqx4', '0b01', '0b01', '01100', 0.192, '11100', 0.203, '2_1__']",
#  "['2017-11-04T21:13:48.557Z', True, 'simulator', '0b01', '0b01', '01100', 0.977, '01100', 0.977, '2_1__']",
#  "['2017-11-04T22:08:27.390Z', True, 'simulator', '0b00', '0b11', '11101', 0.936, '11101', 0.936, '2_1__']",
#  "['2017-11-04T21:21:56.238Z', True, 'simulator', '0b00', '0b11', '11101', 0.945, '11101', 0.945, '2_1__']",
#  "['2017-11-04T21:08:55.169Z', False, 'ibmqx4', '0b10', '0b00', '00100', 0.224, '10100', 0.225, '2_1__']",
#  "['2017-11-04T21:28:58.243Z', True, 'simulator', '0b00', '0b00', '00000', 1.0, '00000', 1.0, '2_1__']",
#  "['2017-11-04T21:06:38.645Z', True, 'simulator', '0b10', '0b00', '00100', 1.0, '00100', 1.0, '2_1__']",
#  "['2017-11-04T22:05:56.364Z', True, 'ibmqx4', '0b01', '0b01', '01100', 0.188, '01100', 0.188, '2_1__']",
#  "['2017-11-04T21:51:46.008Z', True, 'ibmqx4', '0b10', '0b00', '00100', 0.214, '00100', 0.214, '2_1__']",
#  "['2017-11-04T22:10:41.017Z', False, 'ibmqx4', '0b00', '0b00', '00000', 0.149, '10000', 0.304, '2_1__']",
#  "['2017-11-04T22:08:37.405Z', True, 'ibmqx4', '0b00', '0b11', '11101', 0.209, '11101', 0.209, '2_1__']",
#  "['2017-11-04T21:51:16.880Z', True, 'simulator', '0b10', '0b00', '00100', 1.0, '00100', 1.0, '2_1__']",
#  "['2017-11-04T22:10:28.212Z', True, 'simulator', '0b00', '0b00', '00000', 1.0, '00000', 1.0, '2_1__']",
#  "['2017-11-04T22:04:21.171Z', True, 'simulator', '0b01', '0b01', '01100', 0.972, '01100', 0.972, '2_1__']",
#  "['2017-11-04T20:52:44.016Z', True, 'simulator', '0b10', '0b00', '00100', 1.0, '00100', 1.0, '2_1__']",
#  "['2017-12-01T15:59:27.372Z', True, 'simulator', '0b10', '0b11', '11001', 1.0, '11001', 1.0, '2_1__']",
#  "['2017-12-01T15:58:59.732Z', True, 'simulator', '0b01', '0b10', '10101', 1.0, '10101', 1.0, '2_1__']",
#  "['2017-12-01T15:59:49.351Z', True, 'simulator', '0b11', '0b11', '01101', 1.0, '01101', 1.0, '2_1__']",
#  "['2017-12-01T15:58:31.075Z', True, 'simulator', '0b00', '0b01', '11000', 1.0, '11000', 1.0, '2_1__']",
#  "['2017-12-01T15:58:54.223Z', True, 'simulator', '0b01', '0b01', '01100', 1.0, '01100', 1.0, '2_1__']",
#  "['2017-12-01T15:58:25.437Z', True, 'simulator', '0b00', '0b00', '00000', 1.0, '00000', 1.0, '2_1__']",
#  "['2017-12-01T15:59:32.884Z', True, 'simulator', '0b11', '0b00', '10100', 1.0, '10100', 1.0, '2_1__']",
#  "['2017-12-01T15:59:17.210Z', True, 'simulator', '0b10', '0b01', '11100', 1.0, '11100', 1.0, '2_1__']",
#  "['2017-12-01T15:58:36.700Z', True, 'simulator', '0b00', '0b10', '00101', 1.0, '00101', 1.0, '2_1__']",
#  "['2017-12-01T15:58:48.399Z', True, 'simulator', '0b01', '0b00', '10000', 1.0, '10000', 1.0, '2_1__']",
#  "['2017-12-01T15:59:11.594Z', True, 'simulator', '0b10', '0b00', '00100', 1.0, '00100', 1.0, '2_1__']",
#  "['2017-12-01T15:59:05.798Z', True, 'simulator', '0b01', '0b11', '01001', 1.0, '01001', 1.0, '2_1__']",
#  "['2017-12-01T15:58:42.807Z', True, 'simulator', '0b00', '0b11', '11101', 1.0, '11101', 1.0, '2_1__']",
#  "['2017-12-01T15:59:22.296Z', True, 'simulator', '0b10', '0b10', '00001', 1.0, '00001', 1.0, '2_1__']",
#  "['2017-12-01T15:59:44.277Z', True, 'simulator', '0b11', '0b10', '10001', 1.0, '10001', 1.0, '2_1__']",
#  "['2017-12-01T15:59:38.736Z', True, 'simulator', '0b11', '0b01', '01000', 1.0, '01000', 1.0, '2_1__']"]

# %%
def MapToMeaning(row):
    date = row["date"]
    backend = row["backend"]
    m = re.search("// draper\\((.+),(.+)\\)->(\\d+)", row["target"])
    a = m.group(1)
    b = m.group(2)
    counts = row["result"]["data"]["counts"]
    shots = row["shots"]
    expected_result = m.group(3)
    computational_result = max(counts.keys(), key=(lambda key: counts[key]))
    hint_result = "2_1__"
    success = computational_result == expected_result
    computational_result_prob = counts[computational_result]/float(shots)
    expected_result_prob = counts[expected_result]/float(shots)
    
    calibration = row["calibration"]
    
    return str([date,success,backend,a,b,expected_result,expected_result_prob,
                computational_result,computational_result_prob,hint_result])

def FlattenData(x):
    return { 
        'date': x["creationDate"], 
        'target':x["qasms"][0]["qasm"].split('\n')[0], 
        'backend':x["backend"]["name"],
        'result':x["qasms"][0]["result"],
        'calibration':x["calibration"],
        'shots': x["shots"]
    }

# %%
Q_program.get_api().backend_status()
# Out:
# {'available': False, 'backend': 'ibmqx4', 'busy': False, 'pending_jobs': 8}

# %%
np.pi/4
# Out:
# 0.7853981633974483

# %%
(u3(np.pi,np.pi/8,np.pi)*u3(np.pi,-np.pi/8,np.pi)*u3(-np.pi/8,0.0,0.0)).round(6)
# Out:
# matrix([[ 0.906127-0.37533j ,  0.180240-0.074658j],
#         [-0.180240-0.074658j,  0.906127+0.37533j ]])

# %%
u3(np.pi,0.0,0.0).round(6)
# Out:
# matrix([[ 0.+0.j, -1.-0.j],
#         [ 1.+0.j,  0.+0.j]])

# %%
u1(np.pi/4)*u1(np.pi/2)
# Out:
# array([[ 1.00000000+0.j        ,  0.00000000+0.j        ],
#        [ 0.00000000+0.j        , -0.70710678+0.70710678j]])

# %%
u1(np.pi/4+ np.pi/2)
# Out:
# array([[ 1.00000000+0.j        ,  0.00000000+0.j        ],
#        [ 0.00000000+0.j        , -0.70710678+0.70710678j]])
